# %% [markdown]
# # Taller Integrador — Módulo 1
# ## Máster en IA & Data Science | DevSeniorCode
#
# **Nombre del estudiante:** Jhoan Sebastián Perea Montañez
# **Fecha de entrega:** 20/03/2026
# **Repositorio GitHub:** ___________________________
#
# ---
#
# > Este taller evalúa todo lo visto en el Módulo 1:
# > Python · Pandas · Git & GitHub · Documentación
#
# ### ¿Cómo entregar?
# 1. Completa todas las celdas marcadas con
# 2. Asegúrate de que el notebook corra sin errores (Kernel → Restart & Run All)
# 3. Sube el notebook y el CSV a tu repositorio de GitHub
# 4. Incluye un README.md con tu nombre y una descripción breve del proyecto
#
# ---

# %% [markdown]
# ## Contexto del Dataset
#
# Trabajarás con el dataset **`salud_mundial.csv`**, que contiene indicadores de salud de **159 países**.
#
# | Columna | Descripción |
# |---|---|
# | `pais` | Nombre del país |
# | `region` | Continente o región geográfica |
# | `nivel_ingresos` | Nivel económico: Low, Medium, High, Very High |
# | `esperanza_vida` | Esperanza de vida al nacer (años) |
# | `gasto_salud_usd` | Gasto per cápita en salud (USD/año) |
# | `mortalidad_infantil` | Muertes por cada 1,000 nacidos vivos |
# | `medicos_por_1000` | Médicos por cada 1,000 habitantes |
# | `poblacion_urbana_pct` | % de población que vive en zonas urbanas |
# | `obesidad_pct` | % de la población con obesidad |
# | `diabetes_pct` | % de la población con diabetes |
# | `tabaquismo_pct` | % de fumadores |
# | `camas_hospital_por_1000` | Camas hospitalarias por 1,000 hab. |
# | `vacunacion_pct` | % de cobertura de vacunación |
#
# ---

# %% [markdown]
# ---
# ## Parte 1 — Python Fundamental
# ### (30 puntos)
#
# Antes de usar Pandas, demostraremos que dominas las estructuras básicas de Python.
#
# ---

# %% [markdown]
# ### 1.1 — Listas y operaciones básicas
#
# Tienes la siguiente lista con la esperanza de vida de 10 países (en años).

# %%
# Lista dada — NO modificar
esperanzas_de_vida = [72.3, 81.5, 60.1, 78.9, 55.4, 83.2, 67.8, 74.0, 49.3, 79.6]

# %% [markdown]
# **Ejercicio 1.1** — Usando Python puro (sin Pandas ni funciones built-in como `sum()` o `max()`):
# - Calcula el **promedio** de la lista usando un bucle `for`
# - Encuentra el **valor máximo** usando un bucle `for`
# - Encuentra el **valor mínimo** usando un bucle `for`

# %%
# Tu código aquí
suma= 0
contador= 0
maximo= 0
minimo = 100
# Promedio
for vida in esperanzas_de_vida:
    suma += vida
    contador += 1
print(f"El promedio es de: {suma/contador}")

# Máximo
for vida in esperanzas_de_vida:
    if vida> maximo:
        maximo = vida
print(f"maximo es: {maximo}")

# Mínimo
for vida in esperanzas_de_vida:
    if vida < minimo:
        minimo = vida
print(f"minimo es: {minimo}")
# Out:
# El promedio es de: 70.21000000000001
# maximo es: 83.2
# minimo es: 49.3

# %% [markdown]
# ### 1.2 — Diccionarios
#
# Los diccionarios son fundamentales en Data Science para representar registros.

# %% [markdown]
# **Ejercicio 1.2** — Crea un diccionario llamado `pais_info` que represente a Colombia con los siguientes campos:
# - `nombre`: "Colombia"
# - `region`: "Americas"
# - `esperanza_vida`: 76.5
# - `gasto_salud_usd`: 560.3
# - `nivel_ingresos`: "High"
#
# Luego:
# 1. Imprime solo las **claves** del diccionario
# 2. Imprime solo los **valores**
# 3. Agrega un nuevo campo: `vacunacion_pct` con valor 82.1
# 4. Imprime el diccionario completo

# %%
# Tu código aquí
pais_info = {"nombre":"Colombia","region":"Americas","esperanzas_de_vida": 76.5,"gasto_salud_usd":560.3, "nivel_ingresos":"High"}
print(pais_info.keys())
print(pais_info.values())
pais_info["vacunacion_pct"]= 82.1
print(pais_info)
# Out:
# dict_keys(['nombre', 'region', 'esperanzas_de_vida', 'gasto_salud_usd', 'nivel_ingresos'])
# dict_values(['Colombia', 'Americas', 76.5, 560.3, 'High'])
# {'nombre': 'Colombia', 'region': 'Americas', 'esperanzas_de_vida': 76.5, 'gasto_salud_usd': 560.3, 'nivel_ingresos': 'High', 'vacunacion_pct': 82.1}

# %% [markdown]
# ### 1.3 — Funciones
#
# Las funciones nos permiten reutilizar lógica.

# %% [markdown]
# **Ejercicio 1.3** — Crea una función llamada `clasificar_esperanza_vida` que reciba un número (años) y retorne:
# - `"Alta"` si es >= 75
# - `"Media"` si es entre 60 y 74.9
# - `"Baja"` si es < 60
#
# Prueba la función con al menos 5 valores distintos e imprime los resultados.

# %%
# Tu código aquí
def clasificar_esperanza_vida(años):
    if años >= 75:
        return "Alta"
    elif años >= 60:
        return "Media"
    else:
        return "Baja"
print(clasificar_esperanza_vida(76))
print(clasificar_esperanza_vida(53))
print(clasificar_esperanza_vida(43.3))
print(clasificar_esperanza_vida(63))
print(clasificar_esperanza_vida(145.8))
# Out:
# Alta
# Baja
# Baja
# Media
# Alta

# %% [markdown]
# ### 1.4 — Listas + Funciones + Bucles (integrador)

# %% [markdown]
# **Ejercicio 1.4** — Usa la función creada en 1.3 y la lista del ejercicio 1.1 para:
# 1. Crear una **nueva lista** llamada `clasificaciones` que contenga la clasificación de cada esperanza de vida
# 2. Imprimir cada par: `(valor, clasificación)` usando un bucle `for`

# %%
# Tu código aquí
clasificaciones= []
esperanzas_de_vida = [72.3, 81.5, 60.1, 78.9, 55.4, 83.2, 67.8, 74.0, 49.3, 79.6]
def clasificar_esperanza_vida(años):
    if años >= 75:
        return "Alta"
    elif años >= 60:
        return "Media"
    else:
        return "Baja"
for vida in esperanzas_de_vida:
    clasificacion= clasificar_esperanza_vida(vida)
    clasificaciones.append(clasificacion)
    print(vida, clasificacion)
# Out:
# 72.3 Media
# 81.5 Alta
# 60.1 Media
# 78.9 Alta
# 55.4 Baja
# 83.2 Alta
# 67.8 Media
# 74.0 Media
# 49.3 Baja
# 79.6 Alta

# %% [markdown]
# ---
# ## Parte 2 — Análisis con Pandas
# ### (50 puntos)
#
# ---

# %% [markdown]
# ### 2.1 — Carga y exploración inicial

# %% [markdown]
# 🔧 **Ejercicio 2.1** — Importa Pandas y carga el archivo `salud_mundial.csv`.
# Luego ejecuta los comandos necesarios para responder:
# 1. ¿Cuántas filas y columnas tiene el dataset?
# 2. ¿Qué tipos de datos tiene cada columna?
# 3. ¿Cuántos valores nulos hay por columna?
# 4. Muestra las primeras 8 filas

# %%
# Tu código aquí
import pandas as pandita
# Cargar el dataset
df=pandita.read_csv("salud_mundial.csv")

# Dimensiones
print(f"Numero de filas y columnas: {df.shape}")

# Tipos de datos
print(df.info())

# Valores nulos
X=df.isnull().sum()
print(X)
# Primeras 8 filas
df.head(8)
# Out:
# Numero de filas y columnas: (159, 13)
# <class 'pandas.DataFrame'>
# RangeIndex: 159 entries, 0 to 158
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   pais                     159 non-null    str
#  1   region                   159 non-null    str
#  2   nivel_ingresos           159 non-null    str
#  3   esperanza_vida           155 non-null    float64
#  4   gasto_salud_usd          154 non-null    float64
#  5   mortalidad_infantil      149 non-null    float64
#  6   medicos_por_1000         150 non-null    float64
#  7   poblacion_urbana_pct     159 non-null    float64
#  8   obesidad_pct             156 non-null    float64
#  9   diabetes_pct             152 non-null    float64
#  10  tabaquismo_pct           155 non-null    float64
#  11  camas_hospital_por_1000  152 non-null    float64
#  12  vacunacion_pct           155 non-null    float64
# dtypes: float64(10), str(3)
# memory usage: 16.3 KB
# None
# pais                        0
# region                      0
# nivel_ingresos              0
# esperanza_vida              4
# gasto_salud_usd             5
# mortalidad_infantil        10
# medicos_por_1000            9
# poblacion_urbana_pct        0
# obesidad_pct                3
# diabetes_pct                7
# tabaquismo_pct              4
# camas_hospital_por_1000     7
# vacunacion_pct              4
# dtype: int64
#           pais    region nivel_ingresos  esperanza_vida  gasto_salud_usd  \
# 0  Afghanistan      Asia            Low            60.9             18.4
# 1      Albania    Europe         Medium            65.1            673.8
# 2      Algeria    Africa         Medium            74.5            525.3
# 3       Angola    Africa            Low             NaN             37.1
# 4    Argentina  Americas           High            79.4           1809.5
# 5      Armenia    Europe         Medium            69.2            797.5
# 6    Australia   Oceania      Very High             NaN           9964.1
# 7      Austria    Europe      Very High            83.7           3685.2
#
#    mortalidad_infantil  medicos_por_1000  poblacion_urbana_pct  obesidad_pct  \
# 0                  NaN              0.19                  40.8          15.2
# 1                 28.1              1.18                  45.0          27.2
# 2                 28.2              0.59                  47.3          15.2
# 3                 54.7              0.79                  37.4          13.4
# 4                  7.6               NaN                  71.5          18.9
# 5                 24.2              2.44                  67.5          10.2
# 6                  NaN              4.42                  87.2          20.6
# 7                  3.9              2.71                  91.0          31.0
#
#    diabetes_pct  tabaquismo_pct  camas_hospital_por_1000  vacunacion_pct
# 0           9.2            10.1                      1.0            41.1
# 1           9.7            17.3                      1.2            84.5
# 2           7.6            20.8                      1.3            71.4
# 3           7.8            28.2                      1.6            48.7
# 4          10.1            33.0                      3.4            81.7
# 5          12.8            32.0                      2.3            71.1
# 6          10.3            19.7                      7.3            93.8
# 7           5.9            18.6                      6.0            90.9

# %% [markdown]
# ### 2.2 — Limpieza de datos

# %% [markdown]
# 🔧 **Ejercicio 2.2** — El dataset tiene algunos valores nulos (¡datos reales siempre tienen este problema!).
# 1. Rellena los valores nulos de columnas **numéricas** con la **media** de cada columna
# 2. Verifica que ya no queden nulos
# 3. Explica en una celda de texto: ¿Por qué usamos la media y no simplemente eliminamos esas filas?

# %%
# Tu código aqui
Nuevo= df.drop_duplicates()
columnasStr= ["pais","region","nivel_ingresos"]
Media=Nuevo.drop(columns=columnasStr).median() #lo que quise hacer es dejar solo las int, como solo eran 3 str las excluí del calculo o sino daba error.(use la median, en clase y tutorias lo usamos...)
Nuevo=Nuevo.fillna(Media)
Nuevo.isnull().sum()
Nuevo
# Out:
#                     pais    region nivel_ingresos  esperanza_vida  \
# 0            Afghanistan      Asia            Low            60.9
# 1                Albania    Europe         Medium            65.1
# 2                Algeria    Africa         Medium            74.5
# 3                 Angola    Africa            Low            73.2
# 4              Argentina  Americas           High            79.4
# ..                   ...       ...            ...             ...
# 154             Slovenia    Europe      Very High            79.2
# 155             Suriname  Americas         Medium            66.7
# 156            Swaziland    Africa         Medium            69.3
# 157          Timor-Leste      Asia            Low            65.1
# 158  Trinidad and Tobago  Americas           High            77.8
#
#      gasto_salud_usd  mortalidad_infantil  medicos_por_1000  \
# 0               18.4                 21.7              0.19
# 1              673.8                 28.1              1.18
# 2              525.3                 28.2              0.59
# 3               37.1                 54.7              0.79
# 4             1809.5                  7.6              1.69
# ..               ...                  ...               ...
# 154           4043.9                  4.9              5.26
# 155            766.7                 30.2              2.42
# 156            796.3                 34.2              0.56
# 157             75.3                 47.2              0.21
# 158           1157.8                  5.7              3.19
#
#      poblacion_urbana_pct  obesidad_pct  diabetes_pct  tabaquismo_pct  \
# 0                    40.8          15.2           9.2            10.1
# 1                    45.0          27.2           9.7            17.3
# 2                    47.3          15.2           7.6            20.8
# 3                    37.4          13.4           7.8            28.2
# 4                    71.5          18.9          10.1            33.0
# ..                    ...           ...           ...             ...
# 154                  93.1          23.5           5.2            20.6
# 155                  60.8          13.1          14.7            32.3
# 156                  59.3          26.6          14.7            20.5
# 157                  17.4           8.8           3.8             8.0
# 158                  65.1          19.8          12.7            16.5
#
#      camas_hospital_por_1000  vacunacion_pct
# 0                        1.0            41.1
# 1                        1.2            84.5
# 2                        1.3            71.4
# 3                        1.6            48.7
# 4                        3.4            81.7
# ..                       ...             ...
# 154                      8.0            96.5
# 155                      3.3            83.1
# 156                      2.4            86.5
# 157                      0.9            67.8
# 158                      2.2            84.4
#
# [159 rows x 13 columns]

# %% [markdown]
# **Responde aquí** (doble clic para editar):
#
# *¿Por qué usamos la media para rellenar nulos en vez de eliminar las filas?*
#
# > Tu respuesta: Porque en este caso la cantidad de nulos no es tan significativa para decidir eliminar la fila completa, ejemplo si fuesen 90 nulos con respecto a 159, se consideraria la opcion de eliminarla pues no influiria mucho, y para que los datos no varien tanto usamos la media, permitiendo sea equilibrada la data y representativa.

# %% [markdown]
# ### 2.3 — Estadísticas descriptivas

# %% [markdown]
# 🔧 **Ejercicio 2.3**
# 1. Muestra el resumen estadístico completo del dataset
# 2. ¿Cuál es la esperanza de vida **promedio** mundial?
# 3. ¿Cuál es el país con **mayor** gasto en salud? ¿Y el de **menor**?
# 4. ¿Cuál es la **mediana** de la mortalidad infantil?

# %%
# Tu código aquí
print(Nuevo.describe()) #<--Resumen estadistico completo dataset

print("La esperanza de vida promedio mundial es de: ", Nuevo["esperanza_vida"].mean())
print("El pais con mayor gasto de salud es: ", Nuevo[Nuevo["gasto_salud_usd"]==Nuevo["gasto_salud_usd"].max()]["pais"].values[0])
print("El pais con menor gasto de salud es: ", Nuevo[Nuevo["gasto_salud_usd"]==Nuevo["gasto_salud_usd"].min()]["pais"].values[0])
print("La mediana de indice mortalidad infantil es: ",Nuevo["mortalidad_infantil"].median())
# Out:
#        esperanza_vida  gasto_salud_usd  mortalidad_infantil  medicos_por_1000  \
# count      159.000000       159.000000           159.000000        159.000000
# mean        71.138994      2167.524843            28.470440          1.962013
# std          8.604208      2923.190622            25.503508          1.480761
# min         51.100000        18.400000             2.100000          0.030000
# 25%         65.100000       138.800000             5.900000          0.670000
# 50%         73.200000       642.150000            21.700000          1.690000
# 75%         78.850000      3104.900000            43.300000          2.965000
# max         84.000000     10311.800000            95.000000          5.430000
#
#        poblacion_urbana_pct  obesidad_pct  diabetes_pct  tabaquismo_pct  \
# count            159.000000    159.000000    159.000000      159.000000
# mean              58.635220     19.217925      8.837107       22.907547
# std               21.703028      7.145888      2.851239        7.440639
# min               16.200000      5.100000      3.100000        8.000000
# 25%               42.850000     13.600000      6.850000       17.450000
# 50%               57.100000     19.250000      8.700000       22.500000
# 75%               77.950000     24.800000     10.500000       28.600000
# max               96.800000     34.800000     15.000000       40.000000
#
#        camas_hospital_por_1000  vacunacion_pct
# count               159.000000      159.000000
# mean                  3.010063       77.709434
# std                   2.154072       15.484295
# min                   0.300000       40.300000
# 25%                   1.300000       68.400000
# 50%                   2.200000       81.300000
# 75%                   4.300000       89.750000
# max                   8.500000       99.000000
# La esperanza de vida promedio mundial es de:  71.13899371069184
# El pais con mayor gasto de salud es:  Slovakia
# El pais con menor gasto de salud es:  Afghanistan
# La mediana de indice mortalidad infantil es:  21.7

# %% [markdown]
# ### 2.4 — Filtrado y selección

# %% [markdown]
# 🔧 **Ejercicio 2.4**
# 1. Filtra los países de **América** (`region == "Americas"`) y muestra solo las columnas: `pais`, `esperanza_vida`, `gasto_salud_usd`
# 2. Filtra los países con esperanza de vida **mayor a 80 años** — ¿cuántos son? ¿De qué regiones son?
# 3. Filtra los países con **nivel_ingresos == "Low"** y calcula su promedio de `mortalidad_infantil`
# 4. ¿Cuántos países tienen vacunación por encima del 90%?

# %%
# Tu código aquí

America = Nuevo[Nuevo["region"] == "Americas"][["pais","esperanza_vida","gasto_salud_usd"]]
America
EspVida = Nuevo[Nuevo["esperanza_vida"] > 80][["pais","esperanza_vida","region"]]
NPais=EspVida["pais"].count()
regionPaises = EspVida["region"].value_counts()
print(EspVida)
print(f"La cantidad de paises con esperanza de vida mayor a 80 años es de: {NPais} y la cantidad de paises por region es: {regionPaises}")

PaisPoor = Nuevo[Nuevo["nivel_ingresos"] == "Low"]
PromMortalidad = PaisPoor["mortalidad_infantil"].mean()
print(f"El promedio de mortalidad infantil en paises con nivel de ingresos Low es de: {PromMortalidad}")

Vacuna = Nuevo[Nuevo["vacunacion_pct"] > 90][["pais","vacunacion_pct"]]
TVacuna=Vacuna["pais"].count()
print(Vacuna)
print(f"Los paises con porcentaje de vacunacion mayor a 90% son: {TVacuna}")
# Out:
#                      pais  esperanza_vida    region
# 7                 Austria            83.7    Europe
# 10                Belgium            80.5    Europe
# 24         Czech Republic            82.6    Europe
# 25                Denmark            83.4    Europe
# 35                 Greece            81.6    Europe
# 44                Ireland            81.9    Europe
# 45                 Israel            84.0      Asia
# 46                  Italy            83.2    Europe
# 52                 Kuwait            82.5      Asia
# 64            Netherlands            82.9    Europe
# 76               Portugal            81.8    Europe
# 87            South Korea            81.0      Asia
# 88                  Spain            82.4    Europe
# 101  United Arab Emirates            81.1      Asia
# 102        United Kingdom            83.6    Europe
# 103         United States            81.2  Americas
# 114               Iceland            80.9    Europe
# 116            Luxembourg            80.9    Europe
# 129                Brunei            80.2      Asia
# 136               Estonia            84.0    Europe
# 142                Latvia            80.2    Europe
# 148                 Malta            80.1    Europe
# 153              Slovakia            82.2    Europe
# La cantidad de paises con esperanza de vida mayor a 80 años es de: 23 y la cantidad de paises por region es: region
# Europe      17
# Asia         5
# Americas     1
# Name: count, dtype: int64
# El promedio de mortalidad infantil en paises con nivel de ingresos bajo es de: 62.556521739130446
#                      pais  vacunacion_pct
# 6               Australia            93.8
# 7                 Austria            90.9
# 10                Belgium            97.2
# 17                  Chile            91.4
# 23                   Cuba            90.2
# 32                 France            91.6
# 35                 Greece            94.8
# 44                Ireland            97.5
# 46                  Italy            96.9
# 48                  Japan            97.2
# 52                 Kuwait            92.9
# 57               Malaysia            92.1
# 64            Netherlands            93.4
# 69                 Norway            97.2
# 71                 Panama            92.9
# 75                 Poland            91.1
# 76               Portugal            98.3
# 80           Saudi Arabia            99.0
# 82                 Serbia            91.1
# 84              Singapore            97.3
# 87            South Korea            91.9
# 88                  Spain            96.4
# 92            Switzerland            91.9
# 98                 Turkey            94.2
# 101  United Arab Emirates            92.4
# 102        United Kingdom            92.2
# 103         United States            93.9
# 104               Uruguay            90.6
# 114               Iceland            98.6
# 116            Luxembourg            95.8
# 120                  Oman            94.1
# 122                 Qatar            96.3
# 129                Brunei            91.3
# 136               Estonia            92.5
# 142                Latvia            90.7
# 144             Lithuania            97.9
# 148                 Malta            90.7
# 153              Slovakia            97.7
# 154              Slovenia            96.5
# Los paises con porcentaje de vacunacion mayor a 90% son: 39

# %% [markdown]
# ### 2.5 — Agrupaciones

# %% [markdown]
# 🔧 **Ejercicio 2.5** — Usa `groupby()` para:
# 1. Calcular la **esperanza de vida promedio** por `region`
# 2. Calcular el **gasto en salud promedio** por `nivel_ingresos`
# 3. Calcular el **número de países** por región
# 4. ¿Qué región tiene la mayor esperanza de vida promedio? ¿Y la menor?

# %%
# Tu código aquí
print("\nPrimer Ejercicio-----------\n")
EsperanzaVida= Nuevo.groupby("region")["esperanza_vida"].mean()
print(EsperanzaVida)
print("\nSegundo Ejercicio-----------\n")
print(Nuevo.groupby("nivel_ingresos")["gasto_salud_usd"].mean())
print("\nTercer Ejercicio-----------\n")
print(Nuevo.groupby("region")["pais"].count())
print("\nCuarto Ejercicio-----------\n")
print(f"la regió con mayor esperanza de vida es:{EsperanzaVida.idxmax()}")
print(f"La región con menor esperanza de vida es:{EsperanzaVida.idxmin()}")
# Out:
# Primer Ejercicio-----------
#
# region
# Africa      63.562791
# Americas    73.553846
# Asia        70.704762
# Europe      77.700000
# Oceania     69.275000
# Name: esperanza_vida, dtype: float64
#
# Segundo Ejercicio-----------
#
# nivel_ingresos
# High         2003.016000
# Low            92.644565
# Medium        493.339362
# Very High    6514.937805
# Name: gasto_salud_usd, dtype: float64
#
# Tercer Ejercicio-----------
#
# region
# Africa      43
# Americas    26
# Asia        42
# Europe      44
# Oceania      4
# Name: pais, dtype: int64
#
# Tercer Ejercicio-----------
#
# la regió con mayor esperanza de vida es:Europe
# La regiópn con menor esperanza de vida es:Africa

# %% [markdown]
# ### 2.6 — Nueva columna calculada

# %% [markdown]
# 🔧 **Ejercicio 2.6**
# 1. Crea una nueva columna llamada `categoria_vida` aplicando la función `clasificar_esperanza_vida` que creaste en la Parte 1 a la columna `esperanza_vida`
# 2. ¿Cuántos países caen en cada categoría? (usa `value_counts()`)
# 3. ¿Qué porcentaje del total representa cada categoría?

# %%
# Tu código aquí
Nuevo["categoria_vida"]= Nuevo["esperanza_vida"].apply(clasificar_esperanza_vida)
print(Nuevo)
Categorizados =Nuevo["categoria_vida"].value_counts()
print(Categorizados)
Porcentaje=(Categorizados/len(Nuevo))*100
print(f"El procentaje que representa cada categoria de esperanza de vida es: \n ")
print((Porcentaje).round(2).astype(str) + " %")
# Out:
#                     pais    region nivel_ingresos  esperanza_vida  \
# 0            Afghanistan      Asia            Low            60.9
# 1                Albania    Europe         Medium            65.1
# 2                Algeria    Africa         Medium            74.5
# 3                 Angola    Africa            Low            73.2
# 4              Argentina  Americas           High            79.4
# ..                   ...       ...            ...             ...
# 154             Slovenia    Europe      Very High            79.2
# 155             Suriname  Americas         Medium            66.7
# 156            Swaziland    Africa         Medium            69.3
# 157          Timor-Leste      Asia            Low            65.1
# 158  Trinidad and Tobago  Americas           High            77.8
#
#      gasto_salud_usd  mortalidad_infantil  medicos_por_1000  \
# 0               18.4                 21.7              0.19
# 1              673.8                 28.1              1.18
# 2              525.3                 28.2              0.59
# 3               37.1                 54.7              0.79
# 4             1809.5                  7.6              1.69
# ..               ...                  ...               ...
# 154           4043.9                  4.9              5.26
# 155            766.7                 30.2              2.42
# 156            796.3                 34.2              0.56
# 157             75.3                 47.2              0.21
# 158           1157.8                  5.7              3.19
#
#      poblacion_urbana_pct  obesidad_pct  diabetes_pct  tabaquismo_pct  \
# 0                    40.8          15.2           9.2            10.1
# 1                    45.0          27.2           9.7            17.3
# 2                    47.3          15.2           7.6            20.8
# 3                    37.4          13.4           7.8            28.2
# 4                    71.5          18.9          10.1            33.0
# ..                    ...           ...           ...             ...
# 154                  93.1          23.5           5.2            20.6
# 155                  60.8          13.1          14.7            32.3
# 156                  59.3          26.6          14.7            20.5
# 157                  17.4           8.8           3.8             8.0
# 158                  65.1          19.8          12.7            16.5
#
#      camas_hospital_por_1000  vacunacion_pct categoria_vida
# 0                        1.0            41.1          Media
# 1                        1.2            84.5          Media
# 2                        1.3            71.4          Media
# 3                        1.6            48.7          Media
# 4                        3.4            81.7           Alta
# ..                       ...             ...            ...
# 154                      8.0            96.5           Alta
# 155                      3.3            83.1          Media
# 156                      2.4            86.5          Media
# 157                      0.9            67.8          Media
# 158                      2.2            84.4           Alta
#
# [159 rows x 14 columns]
# categoria_vida
# Media    79
# Alta     63
# Baja     17
# Name: count, dtype: int64
# El procentaje que representa cada categoria de esperanza de vida es:
#
# categoria_vida
# Media    49.69 %
# Alta     39.62 %
# Baja     10.69 %
# Name: count, dtype: str

# %% [markdown]
# ### 2.7 — Análisis libre (desafío)

# %% [markdown]
# **Ejercicio 2.7 (Opcional — puntos extra)** — Formula **una pregunta propia** sobre el dataset y respóndela con código.
#
# Ejemplos de preguntas que podrías hacer:
# - ¿Existe relación entre el gasto en salud y la esperanza de vida?
# - ¿Los países con más médicos tienen menor mortalidad infantil?
# - ¿Qué región tiene mayor tasa de obesidad?
#
# **Escribe tu pregunta:**

# %% [markdown]
# ¿La cantidad de medicos, afecta las cifras de enfermedades como diabetes? sí es así describir la relación.

# %%
# Tu código aquí
import matplotlib.pyplot as plt
#generar grafico de barras que relacione cantidad de medicos por pais y enfermedades como tabaquismo, obesidad, diabetes, etc. (puedes elegir una o varias enfermedades)
x = Nuevo["medicos_por_1000"]
y = Nuevo["diabetes_pct"]

# Gráfico
plt.figure(figsize=(8,6))
plt.scatter(x, y)

plt.xlabel("Médicos por 1000 habitantes")
plt.ylabel("Porcentaje de diabetes")
plt.grid()
plt.title("Relación entre médicos y diabetes")
plt.show()
correlacion = Nuevo["medicos_por_1000"].corr(Nuevo["diabetes_pct"]) # quise buscar una funcion que permitiera calcular la correlacion y apoyar mi respuesta matematicamente
print(f"Correlación: {correlacion:.2f}")
print("Quiere decir que no hay una relacion entre el número de medicos y la enfermedaad de diabetes, sugiriendo que el desarrollo de la enfermedad no corresponde a la escazes de medicos")
# Out:
# Correlación: 0.04
# Quiere decir que no hay una relacion entre el número de medicos y la enfermedaad de diabetes, sugiriendo que el desarrollo de la enfermedad no corresponde a la escazes de medicos

# %% [markdown]
# ---
# ## Parte 3 — Git & GitHub
# ### (20 puntos)
#
# Esta parte se evalúa por el **estado real de tu repositorio** en GitHub.
# Documenta los comandos que usaste respondiendo las preguntas en las celdas de texto.
#
# ---

# %% [markdown]
# ### 3.1 — Configuración del repositorio

# %% [markdown]
# **Responde** (doble clic para editar):
#
# **¿Qué comandos usaste para crear e inicializar tu repositorio local?**
# ```bash
# # Tu respuesta:
# cd #para buscar la carpeta aunque es ambiguo pues lo estoy haciendo sobre la carpeta
# git init
# git commit -m "Taller_Modulo_1"
# git add . #Subi los 2 archivos al repo local directamente
#
# ```
#
# **¿Cómo conectaste tu repositorio local con GitHub?**
# ```bash
# # Tu respuesta:
# #entre a gitHub y cree el repo virtual, luego use estos comandos en VS code
# git branch -M main
# git remote add origin https://github.com/Jhoansebs100/Taller_Modulo_1_Data_Science.git
# git push -u origin main
#
# ```

# %% [markdown]
# ### 3.2 — Flujo de trabajo

# %% [markdown]
# **Responde:**
#
# **¿Qué comando usaste para añadir los archivos al staging area?**
# ```bash
# # Tu respuesta:
#
# ```
#
# **¿Qué mensaje de commit escribiste? ¿Por qué elegiste ese mensaje?**
# ```bash
# # Tu respuesta:
#
# ```
#
# **¿Cómo subiste los cambios a GitHub?**
# ```bash
# # Tu respuesta:
#
# ```

# %% [markdown]
# ### 3.3 — Buenas prácticas

# %% [markdown]
# **Responde:**
#
# **¿Qué archivos debería incluir un `.gitignore` en un proyecto de Data Science? Menciona al menos 3 y explica por qué.**
#
# > Tu respuesta:
#
# **¿Cuál es la diferencia entre `git add .` y `git add nombre_archivo`?**
#
# > Tu respuesta:

# %% [markdown]
# ---
# ## Parte 4 — Documentación (README)
# ### (Evaluada en GitHub)
#
# Tu repositorio debe tener un archivo `README.md` que incluya:
#
# - [ ] Título del proyecto
# - [ ] Tu nombre
# - [ ] Descripción del dataset (qué contiene, cuántos países, fuente)
# - [ ] Cómo ejecutar el notebook (instrucciones paso a paso)
# - [ ] Al menos 3 hallazgos o conclusiones del análisis
# - [ ] Tecnologías usadas (Python, Pandas, Jupyter, Git)
#
# ---
#
# ### Checklist de entrega
#
# Antes de hacer tu commit final, verifica:
#
# - [ ] El notebook corre completo sin errores (Kernel → Restart & Run All)
# - [ ] Todas las celdas están completadas
# - [ ] Las celdas de texto tienen tus respuestas
# - [ ] El archivo `salud_mundial.csv` está en el repositorio
# - [ ] El `README.md` está completo
# - [ ] El link al repositorio está en la celda de portada
#
# ---
#
# ## Criterios de evaluación
#
# | Sección | Puntos |
# |---|---|
# | Parte 1 — Python | 30 |
# | Parte 2 — Pandas | 50 |
# | Parte 3 — Git | 20 |
# | README en GitHub | 10 |
# | Ejercicio libre 2.7 | +10 |
# | **Total** | **110** |
